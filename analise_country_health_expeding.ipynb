# %% [markdown]
# <a href="https://colab.research.google.com/github/jorge-queiroz/analise_country_health_expeding/blob/main/analise_country_health_expeding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/bd_drug_expending_world.csv')

# %%
df.head()
# Out:
#   LOCATION  INDICATOR SUBJECT      MEASURE FREQUENCY  TIME   Value Flag Codes
# 0      AUS  PHARMAEXP     TOT  PC_HEALTHXP         A  1971  15.992        NaN
# 1      AUS  PHARMAEXP     TOT  PC_HEALTHXP         A  1972  15.091        NaN
# 2      AUS  PHARMAEXP     TOT  PC_HEALTHXP         A  1973  15.117        NaN
# 3      AUS  PHARMAEXP     TOT  PC_HEALTHXP         A  1974  14.771        NaN
# 4      AUS  PHARMAEXP     TOT  PC_HEALTHXP         A  1975  11.849        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3939 entries, 0 to 3938
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    3939 non-null   object
#  1   INDICATOR   3939 non-null   object
#  2   SUBJECT     3939 non-null   object
#  3   MEASURE     3939 non-null   object
#  4   FREQUENCY   3939 non-null   object
#  5   TIME        3939 non-null   int64
#  6   Value       3939 non-null   float64
#  7   Flag Codes  209 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 246.3+ KB

# %%
df.tail()
# Out:
#      LOCATION  INDICATOR SUBJECT  MEASURE FREQUENCY  TIME    Value Flag Codes
# 3934      BRA  PHARMAEXP     TOT  USD_CAP         A  2015  248.338        NaN
# 3935      BRA  PHARMAEXP     TOT  USD_CAP         A  2016  244.670        NaN
# 3936      BRA  PHARMAEXP     TOT  USD_CAP         A  2017  250.063        NaN
# 3937      BRA  PHARMAEXP     TOT  USD_CAP         A  2018  261.617        NaN
# 3938      BRA  PHARMAEXP     TOT  USD_CAP         A  2019  272.831        NaN

# %%
df.describe()
# Out:
#               TIME        Value
# count  3939.000000  3939.000000
# mean   2000.204874   114.627858
# std      14.029115   197.163483
# min    1970.000000     0.207000
# 25%    1989.000000     1.502500
# 50%    2003.000000    15.008000
# 75%    2012.000000   131.311000
# max    2021.000000  1309.679000

# %%
df100 = df[0:100]

# %%
df100
# Out:
#    LOCATION  INDICATOR SUBJECT      MEASURE FREQUENCY  TIME   Value Flag Codes
# 0       AUS  PHARMAEXP     TOT  PC_HEALTHXP         A  1971  15.992        NaN
# 1       AUS  PHARMAEXP     TOT  PC_HEALTHXP         A  1972  15.091        NaN
# 2       AUS  PHARMAEXP     TOT  PC_HEALTHXP         A  1973  15.117        NaN
# 3       AUS  PHARMAEXP     TOT  PC_HEALTHXP         A  1974  14.771        NaN
# 4       AUS  PHARMAEXP     TOT  PC_HEALTHXP         A  1975  11.849        NaN
# ..      ...        ...     ...          ...       ...   ...     ...        ...
# 95      BEL  PHARMAEXP     TOT  PC_HEALTHXP         A  1985  15.684        NaN
# 96      BEL  PHARMAEXP     TOT  PC_HEALTHXP         A  1986  15.708        NaN
# 97      BEL  PHARMAEXP     TOT  PC_HEALTHXP         A  1987  15.952        NaN
# 98      BEL  PHARMAEXP     TOT  PC_HEALTHXP         A  1988  16.479        NaN
# 99      BEL  PHARMAEXP     TOT  PC_HEALTHXP         A  1989  16.231        NaN
#
# [100 rows x 8 columns]

# %%
data_location_time_value = df[['LOCATION', 'TIME', 'Value']]

# %%
df_country_value = df.filter(data_location_time_value)

# %%
df_country_value
# Out:
#      LOCATION  TIME    Value
# 0         AUS  1971   15.992
# 1         AUS  1972   15.091
# 2         AUS  1973   15.117
# 3         AUS  1974   14.771
# 4         AUS  1975   11.849
# ...       ...   ...      ...
# 3934      BRA  2015  248.338
# 3935      BRA  2016  244.670
# 3936      BRA  2017  250.063
# 3937      BRA  2018  261.617
# 3938      BRA  2019  272.831
#
# [3939 rows x 3 columns]

# %%
df_country_value = df_country_value.dropna()

# %%
df_country_value[df_country_value.LOCATION == 'BRA'].sort_values(by='TIME')
# Out:
#      LOCATION  TIME    Value
# 3924      BRA  2015    1.626
# 3929      BRA  2015   18.249
# 3934      BRA  2015  248.338
# 3925      BRA  2016    1.674
# 3930      BRA  2016   18.259
# 3935      BRA  2016  244.670
# 3926      BRA  2017    1.702
# 3931      BRA  2017   17.972
# 3936      BRA  2017  250.063
# 3927      BRA  2018    1.723
# 3932      BRA  2018   18.200
# 3937      BRA  2018  261.617
# 3928      BRA  2019    1.751
# 3933      BRA  2019   18.216
# 3938      BRA  2019  272.831

# %%
df_country_value.hist('TIME')
# Out:
# array([[<Axes: title={'center': 'TIME'}>]], dtype=object)

# %%
anos = df_country_value['TIME']

# %%
valores = df_country_value['Value']

# %%
plt.plot(anos, valores)
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Valores No Decorrer Do Tempo')

plt.figure(figsize=(20, 15))


plt.show()
